# %% [markdown]
# # Домашнее задание "Центральная Предельная Теорема и Закон Больших Чисел".

# %% [markdown]
# ## Задание.

# %% [markdown]
# В этом задании нужно убедиться, что ЦПТ действительно работает.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n и постройте гистрограммы средних этих выборок.

# %%
rv = sts.dgamma(a = 1)

# %%
sample = rv.rvs(size=1000)

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
# Параметры запуска: размеры выборок и количество повторов генерации
n1 = [1,5,10,15,20,100,1000]
samples_count = 1000
# Массивы для сохранения средних по выборкам
a1 = np.array([])
a2 = []

for n2 in n1:
    for number in range(samples_count):
        # На каждом цикле генерируем выборки разных размеров
        sample1 = rv.rvs(size=n2)
        # Считаем среднее по каждой выборке и добавляем в массив средних
        a1 = np.append(a1, sample1.mean())
        # YOUR CODE HERE
    a2.append(a1)

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1[0]) + ' histogram'
plt.hist(a2[0], density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1[1]) + ' histogram'
plt.hist(a2[1], density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1[3]) + ' histogram'
plt.hist(a2[3], density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1[4]) + ' histogram'
plt.hist(a2[4], density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1[5]) + ' histogram'
plt.hist(a2[5], density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')

# %%
# Строим графики
# Подписи для графиков
label_1 = 'sample of ' + str(n1[6]) + ' histogram'
plt.hist(a2[6], density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
# Out:
# Text(0.5, 0, '$x$')
