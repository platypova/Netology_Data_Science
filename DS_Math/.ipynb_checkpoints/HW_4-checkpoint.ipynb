# %% [markdown]
# # Домашнее задание "Математический анализ. Производная".

# %% [markdown]
# ### Уровень 0:

# %%
from math import cos, sin

# %% [markdown]
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.

# %%
# Первая производная

# %% [markdown]
# $f'(x) = 5x^4 + 8cos(2x) - 3sin(3x+3)$

# %% [markdown]
# $f'(1) = $

# %%
print(5+8*cos(2)-3*sin(6))
# Out:
# 2.5090718022196383

# %%
# Вторая производная

# %% [markdown]
# $f''(x) = 20x^3 - 16sin(2x) - 9cos(3x+3)$

# %% [markdown]
# $f''(1) = $

# %%
print(20-16*sin(2)-9*cos(6))
# Out:
# -3.1902914090642014

# %% [markdown]
# ### Уровень 1:

# %% [markdown]
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Первая производная:

# %% [markdown]
# $f'(x) = 10sin^4(2x+1)cos(2x+1)$

# %%
# Вторая производная:

# %% [markdown]
# $f''(x) = 80sin^3(2x+1)cos^2(2x+1) -20sin(2x+1)sin^4(2x+1)$

# %%
a = np.linspace(-5,6,50)

# %%
def f_one(x):
    return 10*((np.sin(2*x+1))**4)*(np.cos(2*x+1))

# %%
def f_two(x):
    return 80*((np.sin(2*x+1))**3)*((np.cos(2*x+1)**2))-20*(np.sin(2*x+1))**5

# %%
x = np.arange(-5, 5, 0.1)

# %%
# График первой производной:
plt.plot(x,f_one(x))
plt.grid()

# %%
# График второй производной:
plt.plot(x,f_two(x))
plt.grid()
